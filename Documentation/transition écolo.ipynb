# %%
import pandas as pd

# %% [markdown]
# ## Approvisionnement, transformation et consommation d'énergies renouvelables et de déchets

# %%
data = pd.read_csv('dataset/t2020_31.tsv', sep='\t')
data
# Out:
#    unit,indic_eu,geo\time    2004     2005     2006     2007     2008   \
# 0          PC,T2020_31,AL  29.621   31.367   32.070   32.657   32.448
# 1          PC,T2020_31,AT  22.554   24.378   26.340   28.179   28.856
# 2          PC,T2020_31,BA  20.274   19.752   19.213   18.701   16.708
# 3          PC,T2020_31,BE   1.890    2.332    2.633    3.101    3.590
# 4          PC,T2020_31,BG   9.231    9.173    9.415    9.098   10.345
# 5          PC,T2020_31,CY   3.071    3.131    3.263    4.004    5.134
# 6          PC,T2020_31,CZ   6.774    7.115    7.363    7.895    8.675
# 7          PC,T2020_31,DE   6.211    7.175    8.477   10.054   10.088
# 8          PC,T2020_31,DK  14.840   15.955   16.335   17.748   18.545
# 9        PC,T2020_31,EA19   8.384    8.972    9.661   10.741   11.432
# 10         PC,T2020_31,EE  18.384   17.421   15.965   17.046   18.643
# 11         PC,T2020_31,EL   7.161    7.277    7.458    8.249    8.183
# ...

# %% [markdown]
# ## Productivité de l'énergie

# %%
data2 = pd.read_csv('dataset/t2020_rd310.tsv', sep='\t')
data2
# Out:
#    unit,geo\time   2000    2001    2002    2003    2004    2005    2006   \
# 0    EUR_KGOE,AT  8.688   8.340   8.429   8.083   8.151   8.061   8.265
# 1    EUR_KGOE,BA      :       :       :       :       :       :       :
# 2    EUR_KGOE,BE  4.730   4.829   4.953   4.767   4.906   5.051   5.182
# 3    EUR_KGOE,BG  1.315   1.306   1.417   1.451   1.587   1.607   1.666
# 4    EUR_KGOE,CY  5.344   5.503   5.786   5.513   6.323   6.004   6.062
# ..           ...     ...     ...     ...     ...     ...     ...     ...
# 73   PPS_KGOE,SE  4.449   4.236   4.275   4.481   4.559   4.723   5.193
# 74   PPS_KGOE,SI  4.613   4.617   4.819   4.979   5.186   5.320   5.569
# 75   PPS_KGOE,SK  2.872   2.982   3.147   3.374   3.660   3.915   4.357
# 76   PPS_KGOE,TR  6.479   6.870   6.579   6.503   7.182   7.656   7.857
# 77   PPS_KGOE,UK  5.489   5.749   6.078   6.257   6.665   6.822   7.204
#
#      2007    2008    2009    2010    2011    2012     2013    2014    2015   \
# ...

# %%
data3 = pd.read_csv('dataset/ETS_Database_v38.csv', sep='\t')
data3
# Out:
#        country country_code  \
# 0      Belgium           BE
# 1      Belgium           BE
# 2      Belgium           BE
# 3      Belgium           BE
# 4      Belgium           BE
# ...        ...          ...
# 57389  Hungary           HU
# 57390  Hungary           HU
# 57391  Hungary           HU
# 57392  Hungary           HU
# 57393  Ireland           IE
#
#                                          ETS information  \
# 0                                  2. Verified emissions
# 1                                  2. Verified emissions
# 2                                  2. Verified emissions
# 3                             4. Total surrendered units
# 4                             4. Total surrendered units
# ...                                                  ...
# 57389                              2. Verified emissions
# 57390  1.1.3 Free allocation for modernisation of ele...
# 57391  1.1.3 Free allocation for modernisation of ele...
# ...

# %% [markdown]
# ## Production d'électricité et de chaleur par type de combustible

# %%
data4 = pd.read_csv('dataset/nrg_bal_peh.tsv', sep='\t')
data4.head(59)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d41f42bea15f> in <module>
# ----> 1 data4 = pd.read_csv('dataset/nrg_bal_peh.tsv', sep='\t')
#       2 data4.head(59)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Bilan énergétique simplifié

# %%
data4 = pd.read_csv('dataset/nrg_bal_s.tsv', sep='\t')
data4
# Out:
#         nrg_bal,siec,unit,geo\time      2018       2017       2016   \
# 0       AFC,C0000X0350-0370,GWH,AL  2598.407   1348.788    589.976
# 1       AFC,C0000X0350-0370,GWH,AT  4111.010   4205.522   4376.613
# 2       AFC,C0000X0350-0370,GWH,BA  3243.089   3080.546   3209.039
# 3       AFC,C0000X0350-0370,GWH,BE  9096.112   8535.415   8937.946
# 4       AFC,C0000X0350-0370,GWH,BG  6778.088   5087.590   4601.471
# ...                            ...        ...        ...        ...
# 138919     TO_RPI,W6100_6220,TJ,SK        : z        : z        : z
# 138920     TO_RPI,W6100_6220,TJ,TR        : z        : z        : z
# 138921     TO_RPI,W6100_6220,TJ,UA        : z        : z        : z
# 138922     TO_RPI,W6100_6220,TJ,UK        : z        : z        : z
# 138923     TO_RPI,W6100_6220,TJ,XK        : z        : z        : z
#
#             2015       2014       2013       2012       2011       2010   ...  \
# ...
